# %%
# import packages 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import os 
import sys
import seaborn as sns
import scipy as sp
import scipy.stats as stats
from scipy.stats import norm
import xgboost
# %matplotlib inline


# import pre-processing modules 
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel 
from sklearn.compose import make_column_selector as selector
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline


# import classifiers
# scale robust
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# scale sensitive
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC

# import evaluation modules
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, classification_report
from sklearn.metrics import  RocCurveDisplay, roc_auc_score, auc, roc_curve, PrecisionRecallDisplay, precision_recall_curve

# %%
test_set = pd.read_csv(r"C:/Users/Yehonatan/PycharmProject/DS/projects/titanic/ignore/test.csv")
train_set = pd.read_csv(r"C:/Users/Yehonatan/PycharmProject/DS/projects/titanic/ignore/train.csv")
df_original = pd.concat([train_set,test_set], axis=0, ignore_index=True )

df_train = (train_set.copy()).rename(columns=str.lower)
df_test = (test_set.copy()).rename(columns=str.lower)

df = (df_original.copy()).rename(columns=str.lower)

# %%
# parse title and fam name from df 
def parse_name(df):
    last_name = df['name'].apply(lambda x : x.split(', ')[0])
    temp = df['name'].apply(lambda x : x.split(', ')[1])
    title = temp.apply(lambda x : x.split('.')[0])
    return title, last_name

def cat_to_numeric(df):
    cat_columns = df.select_dtypes(['object']).columns
    df[cat_columns] = df[cat_columns].apply(lambda x: pd.factorize(x)[0])
    return df 

def pvalue_filter(target_df, features_df, alpha): # returns a list of columns that are possible drop, p_val > alpha, corr, pval
    features_columns_names = list(features_df)
    target_column_name = list(target_df)
    features_np = features_df.to_numpy()
    target_np = target_df.to_numpy()
    drop_index = []
    p_val_list =[]
    corr_list = []
    
    for i in range(len(features_columns_names)):
        corr, p_val = sp.stats.pearsonr(features_np[:,i], target_np)
        corr_list.append(round(corr,3))
        if p_val > alpha:           # accept the null hypothesis, no statisitcal significance  
            drop_index.append(i)
            p_val_list.append(p_val)
            
    drop_col = [features_columns_names[i] for i in drop_index]
    return drop_col, corr_list, p_val_list

# %%
# work on df nan and then concat with original df_train and sort by ID
age_nan = df[df['age'].isna()]
#age_nan.info()
#age_nan = age_nan.sort_values(by=['sex'],ascending=True)
#age_nan = age_nan.sort_values(by=['sibsp'],ascending=False).reset_index(drop=True)
print('df  age nans',df['age'].isna().sum())
# Out:
# df  age nans 263

# %% [markdown]
# ## deal with age nans

# %%
###### Deal with masters  ############################################
title, last_name = parse_name(age_nan)
title = title[title == 'Master']
master_index = title.index.to_numpy()

df_young = df[df["age"] < 15 ]
child_mean = round(df_young['age'].mean(),2)
       
for i in master_index:
    df.at[i,'age'] = child_mean 

age_nan = df[df['age'].isna()] # update the age_nan

####### DEAL  with lone passengers ############################################

l_p_t = age_nan[age_nan['sibsp'] == 0]
lone_pass = l_p_t[l_p_t['parch'] == 0] # passengers who travel alone and cant determine their age by relatives
#lone_pass

# calc mean by gender
df_male = df[df['sex'] == 'male']
df_female = df[df['sex'] == 'female']
male_mean = round(df_male['age'].mean(),2)
female_mean = round(df_female['age'].mean(),2)

lone_pass_male = lone_pass[lone_pass['sex'] == 'male']
lone_pass_female = lone_pass[lone_pass['sex'] == 'female']

l_p_m_index = (lone_pass_male.index).to_numpy()
l_p_f_index = (lone_pass_female.index).to_numpy()

for m in l_p_m_index:
    df.at[m,'age'] = male_mean

for f in l_p_f_index:
    df.at[f,'age'] = female_mean
    
age_nan = df[df['age'].isna()] # update the age_nan



########## ONE companion ############################################################
# one companion in nan df # assign the age of the companion tot the nan 
one_comp_nan = age_nan[age_nan['parch'] == 0] 
one_comp_nan = one_comp_nan[one_comp_nan['sibsp'] == 1]
title_ocn, last_name_ocn = parse_name(one_comp_nan)
ocn_index = (title_ocn.index).to_numpy()


one_comp = df[df['parch'] == 0] # one companion in general df may contain istself. but some companions are both nan in age
one_comp = one_comp[one_comp['sibsp'] == 1]
#one_comp = one_comp[~one_comp['age'].isna()]
title_oc, last_name_oc = parse_name(one_comp)
oc_index = (title_oc.index).to_numpy()

for l in range(len(one_comp_nan)):
    for i in range(len(one_comp)):
        
        if (list(last_name_ocn)[l] == list(last_name_oc)[i] and ocn_index[l] != oc_index[i]): #ensures same last name and not same person
        
            if df.at[oc_index[i],'age'] != float('nan'):
                df.at[ocn_index[l],'age'] =  df.at[oc_index[i],'age'] 
            if list(title_ocn)[l] == 'Mrs' : # she and her husbnad are adults and get the adult average
                df.at[ocn_index[l],'age'] = female_mean
                df.at[oc_index[i],'age'] = male_mean
            if list(title_ocn)[l] == 'Miss': # she is a miss and I assume that travels with a sibling so get young average
                df.at[ocn_index[l],'age'] = child_mean
                df.at[oc_index[i],'age'] = child_mean
            if list(title_ocn)[l] == 'Mr' and list(title_oc)[i] != 'Mrs':
                df.at[ocn_index[l],'age'] = child_mean
                df.at[oc_index[i],'age'] = child_mean


age_nan = df[df['age'].isna()] # update the age_nan

# notice there are only two famillies with 3 siblings travelling together I assume they are all young <15.
three_siblings = age_nan[age_nan['parch'] == 0] 
three_siblings = three_siblings[three_siblings['sibsp'] == 2]
index_temp = three_siblings.index.to_numpy()
for i in index_temp:
    df.at[i,'age'] = child_mean

age_nan = df[df['age'].isna()] # update the age_nan

########### Hand fill age nans #######################################################


# hand fill, thought it will be quicker than thinking about an algo  
#parents
df.at[1233, 'age'] = male_mean
df.at[1256, 'age'] = female_mean
#kids
sages = df[df['ticket'] == 'CA. 2343']
sages = sages[sages['age'].isna()]

index_temp = sages.index.to_numpy()
for i in index_temp:
    df.at[i,'age'] = child_mean
age_nan = df[df['age'].isna()] # update the age_nan

df.at[1023, 'age'] = female_mean
lebfre = df[df['ticket'] == '4133']
lebfre = lebfre[lebfre['age'].isna()]
index_temp = lebfre.index.to_numpy()
for i in index_temp:
    df.at[i,'age'] = child_mean
age_nan = df[df['age'].isna()] # update the age_nan

#jhonston
#parents
df.at[783, 'age'] = male_mean
df.at[924, 'age'] = female_mean
df.at[888,'age'] = child_mean
age_nan = df[df['age'].isna()] # update the age_nan

df.at[1024, 'age'] = male_mean # has no sibsp as I looked
df.at[128, 'age'] = child_mean
df.at[593, 'age'] = child_mean
df.at[166, 'age'] = female_mean
df.at[533, 'age'] = female_mean
df.at[593, 'age'] = female_mean
df.at[1116, 'age'] = female_mean
df.at[140, 'age'] = female_mean
age_nan = df[df['age'].isna()] # update the age_nan

# %%
# deal with cabin nan by comparing the ticket number 
# small number of nans but I know for certain that they get the correct cabin
df['relatives'] = df['parch'] + df['sibsp'] # for later use 

cabin = df[~df['cabin'].isna()]
cabin_nan =  df[df['cabin'].isna()]
print('df  cabin nans',df['cabin'].isna().sum())

for t in range(len(cabin['ticket'])):
    for n in range(len(cabin_nan['ticket'])):
        if cabin['ticket'].iloc[t] == cabin_nan['ticket'].iloc[n] :
           
            index = cabin['passengerid'].iloc[t] - 1    
            index_nan = cabin_nan['passengerid'].iloc[n] - 1 
            if index != index_nan:

                # update the value of cabin_nan in the df
                df.at[index_nan,'cabin'] = df.at[index,'cabin']



cabin_nan =  df[df['cabin'].isna()] # update cabin_nan
print('df cabin nans updated',len(cabin_nan))    


# handle single men and single women in seconde and thied class 

s_t_class_cabin = cabin[cabin['pclass'] != 1] 
single_temp = s_t_class_cabin[s_t_class_cabin['sibsp'] == 0]
single_cabin = single_temp[single_temp['parch'] == 0]

s_t_class_cabin_female = single_cabin[single_cabin['sex'] == 'female'] # single 2 3 class female

s_t_class_cabin_nan = cabin_nan[cabin_nan['pclass'] != 1]
single_temp = s_t_class_cabin_nan[s_t_class_cabin_nan['sibsp'] == 0]
single_cabin_nan = single_temp[single_temp['parch'] == 0]


s_t_class_cabin_nan_female = single_cabin_nan[single_cabin_nan['sex'] == 'female']

# deal with female. compare fare  
#why separated - coz generlizing the cabin nan in male might be different   

for t in range(len(s_t_class_cabin_female)):
    for n in range(len(s_t_class_cabin_nan_female)):
        if s_t_class_cabin_female['fare'].iloc[t] == s_t_class_cabin_nan_female['fare'].iloc[n] :
            
            pclass_cabin = s_t_class_cabin_female['pclass'].iloc[t]              
            pclass_cabin_nan = s_t_class_cabin_nan_female['pclass'].iloc[n]
            index = s_t_class_cabin_female['passengerid'].iloc[t] - 1    
            index_nan = s_t_class_cabin_nan_female['passengerid'].iloc[n] - 1 
            
            if index != index_nan and pclass_cabin == pclass_cabin_nan : # make sure the deduction about cabin doesnt cross pclass

                df.at[index_nan,'cabin'] = df.at[index,'cabin'] # update the value of cabin_nan in the df

cabin_nan =  df[df['cabin'].isna()] 
print('df cabin nans updated',len(cabin_nan))    

# deal with the rest
# Out:
# df  cabin nans 1014
# df cabin nans updated 998
# df cabin nans updated 981

# %%
df['livability'] = 'e'

for p in range(len(df)):
    print(p)
    if df['relatives'].iloc[p] != 0: # non singles
        print('nonsingle')
        # third class
        if df['pclass'].iloc[p] == 3 and df['sex'].iloc[p] == 'male':
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 17:
                df['livability'].iloc[p] = 'l'
            elif prob > 17:
                    df['livability'].iloc[p] = 'D'

        if df['pclass'].iloc[p] == 3 and df['sex'].iloc[p] == 'female':
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob < 40:
                df['livability'].iloc[p] = 'l'
            elif prob >= 40:
                    df['livability'].iloc[p] = 'D'

        # second class
        if df['pclass'].iloc[p] == 2 and df['sex'].iloc[p] == 'male':
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 22:
                df['livability'][p] = 'l'
            elif prob > 22:
                    df['livability'][p] = 'D'

        if df['pclass'].iloc[p] == 2 and df['sex'].iloc[p] == 'female':
            index = df['passengerid'].iloc[p] - 1
            p = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if p <= 93:
                df['livability'][p] = 'l'
            elif p > 93:
                    df['livability'][p] = 'D'

        # first class
        if df['pclass'].iloc[p] == 1 and df['sex'].iloc[p] == 'male':
            index = df['passengerid'].iloc[p] - 1
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 25:
                df['livability'][p] = 'l'
            elif prob > 25:
                    df['livability'][p] = 'D'

        if df['pclass'].iloc[p] == 1 and df['sex'].iloc[p] == 'female':
            index = df['passengerid'].iloc[p] - 1
            df.at[p,'cabin'] = 'l'
            
    
    elif df['relatives'].iloc[p] == 0: # singles
        print('single')
        # third class
        if df['pclass'].iloc[p] == 3 and df['sex'].iloc[p] == 'male':
            index = df['passengerid'].iloc[p] - 1
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 12:
                df['livability'][p] = 'l'
            elif prob > 12:
                    df['livability'][p] = 'D'

        if df['pclass'].iloc[p] == 3 and df['sex'].iloc[p] == 'female':
            index = df['passengerid'].iloc[p] - 1
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 60:
                df['livability'][p] = 'l'
            elif prob > 60:
                    df['livability'][p] = 'D'

        # second class
        if df['pclass'].iloc[p] == 2 and df['sex'].iloc[p] == 'male':
            index = df['passengerid'].iloc[p] - 1
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 9:
                df['livability'][p] = 'l'
            elif prob > 9:
                    df['livability'][p] = 'D'

        if df['pclass'].iloc[p] == 2 and df['sex'].iloc[p] == 'female':
            index = df['passengerid'].iloc[p] - 1
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 91:
                df['livability'][p] = 'l'
            elif prob > 91:
                    df['livability'][p] = 'D'

        # first class
        if df['pclass'].iloc[p] == 1 and df['sex'].iloc[p] == 'male':
            index = df['passengerid'].iloc[p] - 1
            prob = np.random.randint(low=1, high=101, size=1, dtype=int)[0]
            if prob <= 22:
                df['livability'][p] = 'l'
            elif prob > 22:
                    df['livability'][p] = 'D'

        if df['pclass'].iloc[p] == 1 and df['sex'].iloc[p] == 'female':
            index = df['passengerid'].iloc[p] - 1
            df['livability'][p] = 'l'
# Out:
# 0
# nonsingle
# 1
# nonsingle
# 2
# single
# 3
# nonsingle
# 4
# single
# 5
# single
# 6
# single
# 7
# nonsingle
# 8
# nonsingle
# 9
# nonsingle
# 10
# nonsingle
# 11
# single
# 12
# single
# 13
# nonsingle
# 14
# single
# 15
# single
# 16
# nonsingle
# 17
# single
# 18
# nonsingle
# 19
# single
# 20
# single
# 21
# single
# 22
# single
# 23
# single
# 24
# nonsingle
# 25
# nonsingle
# 26
# single
# 27
# nonsingle
# 28
# single
# 29
# single
# 30
# single
# 31
# nonsingle
# 32
# single
# 33
# single
# 34
# nonsingle
# 35
# nonsingle
# 36
# single
# 37
# single
# 38
# nonsingle
# 39
# nonsingle
# 40
# nonsingle
# 41
# nonsingle
# 42
# single
# 43
# nonsingle
# 44
# single
# 45
# single
# 46
# nonsingle
# 47
# single
# 48
# nonsingle
# 49
# nonsingle
# 50
# nonsingle
# 51
# single
# 52
# nonsingle
# 53
# nonsingle
# 54
# nonsingle
# 55
# single
# 56
# single
# 57
# single
# 58
# nonsingle
# 59
# nonsingle
# 60
# single
# 61
# single
# 62
# nonsingle
# 63
# nonsingle
# 64
# single
# 65
# nonsingle
# 66
# single
# 67
# single
# 68
# nonsingle
# 69
# nonsingle
# 70
# single
# 71
# nonsingle
# 72
# single
# 73
# nonsingle
# 74
# single
# 75
# single
# 76
# single
# 77
# single
# 78
# nonsingle
# 79
# single
# 80
# single
# 81
# single
# 82
# single
# 83
# single
# 84
# single
# 85
# nonsingle
# 86
# nonsingle
# 87
# single
# 88
# nonsingle
# 89
# single
# 90
# single
# 91
# single
# 92
# nonsingle
# 93
# nonsingle
# 94
# single
# 95
# single
# 96
# single
# 97
# nonsingle
# 98
# nonsingle
# 99
# nonsingle
# 100
# single
# 101
# single
# 102
# nonsingle
# 103
# single
# 104
# nonsingle
# 105
# single
# 106
# single
# 107
# single
# 108
# single
# 109
# nonsingle
# 110
# single
# 111
# nonsingle
# 112
# single
# 113
# nonsingle
# 114
# single
# 115
# single
# 116
# single
# 117
# nonsingle
# 118
# nonsingle
# 119
# nonsingle
# 120
# nonsingle
# 121
# single
# 122
# nonsingle
# 123
# single
# 124
# nonsingle
# 125
# nonsingle
# 126
# single
# 127
# single
# 128
# nonsingle
# 129
# single
# 130
# single
# 131
# single
# 132
# nonsingle
# 133
# nonsingle
# 134
# single
# 135
# single
# 136
# nonsingle
# 137
# nonsingle
# 138
# single
# 139
# single
# 140
# nonsingle
# 141
# single
# 142
# nonsingle
# 143
# single
# 144
# single
# 145
# nonsingle
# 146
# single
# 147
# nonsingle
# 148
# nonsingle
# 149
# single
# 150
# single
# 151
# nonsingle
# 152
# single
# 153
# nonsingle
# 154
# single
# 155
# nonsingle
# 156
# single
# 157
# single
# 158
# single
# 159
# nonsingle
# 160
# nonsingle
# 161
# single
# 162
# single
# 163
# single
# 164
# nonsingle
# 165
# nonsingle
# 166
# nonsingle
# 167
# nonsingle
# 168
# single
# 169
# single
# 170
# single
# 171
# nonsingle
# 172
# nonsingle
# 173
# single
# 174
# single
# 175
# nonsingle
# 176
# nonsingle
# 177
# single
# 178
# single
# 179
# single
# 180
# nonsingle
# 181
# single
# 182
# nonsingle
# 183
# nonsingle
# 184
# nonsingle
# 185
# single
# 186
# nonsingle
# 187
# single
# 188
# nonsingle
# 189
# single
# 190
# single
# 191
# single
# 192
# nonsingle
# 193
# nonsingle
# 194
# single
# 195
# single
# 196
# single
# 197
# nonsingle
# 198
# single
# 199
# single
# 200
# single
# 201
# nonsingle
# 202
# single
# 203
# single
# 204
# single
# 205
# nonsingle
# 206
# nonsingle
# 207
# single
# 208
# single
# 209
# single
# 210
# single
# 211
# single
# 212
# single
# 213
# single
# 214
# nonsingle
# 215
# nonsingle
# 216
# single
# 217
# nonsingle
# 218
# single
# 219
# single
# 220
# single
# 221
# single
# 222
# single
# 223
# single
# 224
# nonsingle
# 225
# single
# 226
# single
# 227
# single
# 228
# single
# 229
# nonsingle
# 230
# nonsingle
# 231
# single
# 232
# single
# 233
# nonsingle
# 234
# single
# 235
# single
# 236
# nonsingle
# 237
# nonsingle
# 238
# single
# 239
# single
# 240
# nonsingle
# 241
# nonsingle
# 242
# single
# 243
# single
# 244
# single
# 245
# nonsingle
# 246
# single
# 247
# nonsingle
# 248
# nonsingle
# 249
# nonsingle
# 250
# single
# 251
# nonsingle
# 252
# single
# 253
# nonsingle
# 254
# nonsingle
# 255
# nonsingle
# 256
# single
# 257
# single
# 258
# single
# 259
# nonsingle
# 260
# single
# 261
# nonsingle
# 262
# nonsingle
# 263
# single
# 264
# single
# 265
# single
# 266
# nonsingle
# 267
# nonsingle
# 268
# nonsingle
# 269
# single
# 270
# single
# 271
# single
# 272
# nonsingle
# 273
# nonsingle
# 274
# single
# 275
# nonsingle
# 276
# single
# 277
# single
# 278
# nonsingle
# 279
# nonsingle
# 280
# single
# 281
# single
# 282
# single
# 283
# single
# 284
# single
# 285
# single
# 286
# single
# 287
# single
# 288
# single
# 289
# single
# 290
# single
# 291
# nonsingle
# 292
# single
# 293
# single
# 294
# single
# 295
# single
# 296
# single
# 297
# nonsingle
# 298
# single
# 299
# nonsingle
# 300
# single
# 301
# nonsingle
# 302
# single
# 303
# single
# 304
# single
# 305
# nonsingle
# 306
# single
# 307
# nonsingle
# 308
# nonsingle
# 309
# single
# 310
# single
# 311
# nonsingle
# 312
# nonsingle
# 313
# single
# 314
# nonsingle
# 315
# single
# 316
# nonsingle
# 317
# single
# 318
# nonsingle
# 319
# nonsingle
# 320
# single
# 321
# single
# 322
# single
# 323
# nonsingle
# 324
# nonsingle
# 325
# single
# 326
# single
# 327
# single
# 328
# nonsingle
# 329
# nonsingle
# 330
# nonsingle
# 331
# single
# 332
# nonsingle
# 333
# nonsingle
# 334
# nonsingle
# 335
# single
# 336
# nonsingle
# 337
# single
# 338
# single
# 339
# single
# 340
# nonsingle
# 341
# nonsingle
# 342
# single
# 343
# single
# 344
# single
# 345
# single
# 346
# single
# 347
# nonsingle
# 348
# nonsingle
# 349
# single
# 350
# single
# 351
# single
# 352
# nonsingle
# 353
# nonsingle
# 354
# single
# 355
# single
# 356
# nonsingle
# 357
# single
# 358
# single
# 359
# single
# 360
# nonsingle
# 361
# nonsingle
# 362
# nonsingle
# 363
# single
# 364
# nonsingle
# 365
# single
# 366
# nonsingle
# 367
# single
# 368
# single
# 369
# single
# 370
# nonsingle
# 371
# nonsingle
# 372
# single
# 373
# single
# 374
# nonsingle
# 375
# nonsingle
# 376
# single
# 377
# nonsingle
# 378
# single
# 379
# single
# 380
# single
# 381
# nonsingle
# 382
# single
# 383
# nonsingle
# 384
# single
# 385
# single
# 386
# nonsingle
# 387
# single
# 388
# single
# 389
# single
# 390
# nonsingle
# 391
# single
# 392
# nonsingle
# 393
# nonsingle
# 394
# nonsingle
# 395
# single
# 396
# single
# 397
# single
# 398
# single
# 399
# single
# 400
# single
# 401
# single
# 402
# nonsingle
# 403
# nonsingle
# 404
# single
# 405
# nonsingle
# 406
# single
# 407
# nonsingle
# 408
# single
# 409
# nonsingle
# 410
# single
# 411
# single
# 412
# nonsingle
# 413
# single
# 414
# single
# 415
# single
# 416
# nonsingle
# 417
# nonsingle
# 418
# single
# 419
# nonsingle
# 420
# single
# 421
# single
# 422
# single
# 423
# nonsingle
# 424
# nonsingle
# 425
# single
# 426
# nonsingle
# 427
# single
# 428
# single
# 429
# single
# 430
# single
# 431
# nonsingle
# 432
# nonsingle
# 433
# single
# 434
# nonsingle
# 435
# nonsingle
# 436
# nonsingle
# 437
# nonsingle
# 438
# nonsingle
# 439
# single
# 440
# nonsingle
# 441
# single
# 442
# nonsingle
# 443
# single
# 444
# single
# 445
# nonsingle
# 446
# nonsingle
# 447
# single
# 448
# nonsingle
# 449
# single
# 450
# nonsingle
# 451
# nonsingle
# 452
# single
# 453
# nonsingle
# 454
# single
# 455
# single
# 456
# single
# 457
# nonsingle
# 458
# single
# 459
# single
# 460
# single
# 461
# single
# 462
# single
# 463
# single
# 464
# single
# 465
# single
# 466
# single
# 467
# single
# 468
# single
# 469
# nonsingle
# 470
# single
# 471
# single
# 472
# nonsingle
# 473
# single
# 474
# single
# 475
# single
# 476
# nonsingle
# 477
# nonsingle
# 478
# single
# 479
# nonsingle
# 480
# nonsingle
# 481
# single
# 482
# single
# 483
# single
# 484
# nonsingle
# 485
# nonsingle
# 486
# nonsingle
# 487
# single
# 488
# single
# 489
# nonsingle
# 490
# nonsingle
# 491
# single
# 492
# single
# 493
# single
# 494
# single
# 495
# single
# 496
# nonsingle
# 497
# single
# 498
# nonsingle
# 499
# single
# 500
# single
# 501
# single
# 502
# single
# 503
# single
# 504
# single
# 505
# nonsingle
# 506
# nonsingle
# 507
# single
# 508
# single
# 509
# single
# 510
# single
# 511
# single
# 512
# single
# 513
# nonsingle
# 514
# single
# 515
# single
# 516
# single
# 517
# single
# 518
# nonsingle
# 519
# single
# 520
# single
# 521
# single
# 522
# single
# 523
# nonsingle
# 524
# single
# 525
# single
# 526
# single
# 527
# single
# 528
# single
# 529
# nonsingle
# 530
# nonsingle
# 531
# single
# 532
# nonsingle
# 533
# nonsingle
# 534
# single
# 535
# nonsingle
# 536
# single
# 537
# single
# 538
# single
# 539
# nonsingle
# 540
# nonsingle
# 541
# nonsingle
# 542
# nonsingle
# 543
# nonsingle
# 544
# nonsingle
# 545
# single
# 546
# nonsingle
# 547
# single
# 548
# nonsingle
# 549
# nonsingle
# 550
# nonsingle
# 551
# single
# 552
# single
# 553
# single
# 554
# single
# 555
# single
# 556
# nonsingle
# 557
# single
# 558
# nonsingle
# 559
# nonsingle
# 560
# single
# 561
# single
# 562
# single
# 563
# single
# 564
# single
# 565
# nonsingle
# 566
# single
# 567
# nonsingle
# 568
# single
# 569
# single
# 570
# single
# 571
# nonsingle
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'].iloc[p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'].iloc[p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'].iloc[p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'].iloc[p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'l'
# 572
# single
# 573
# single
# 574
# single
# 575
# single
# 576
# single
# 577
# nonsingle
# 578
# nonsingle
# 579
# single
# 580
# nonsingle
# 581
# nonsingle
# 582
# single
# 583
# single
# 584
# single
# 585
# nonsingle
# 586
# single
# 587
# nonsingle
# 588
# single
# 589
# single
# 590
# single
# 591
# nonsingle
# 592
# single
# 593
# nonsingle
# 594
# nonsingle
# 595
# nonsingle
# 596
# single
# 597
# single
# 598
# single
# 599
# nonsingle
# 600
# nonsingle
# 601
# single
# 602
# single
# 603
# single
# 604
# single
# 605
# nonsingle
# 606
# single
# 607
# single
# 608
# nonsingle
# 609
# single
# 610
# nonsingle
# 611
# single
# 612
# nonsingle
# 613
# single
# 614
# single
# 615
# nonsingle
# 616
# nonsingle
# 617
# nonsingle
# 618
# nonsingle
# 619
# single
# 620
# nonsingle
# 621
# nonsingle
# 622
# nonsingle
# 623
# single
# 624
# single
# 625
# single
# 626
# single
# 627
# single
# 628
# single
# 629
# single
# 630
# single
# 631
# single
# 632
# single
# 633
# single
# 634
# nonsingle
# 635
# single
# 636
# single
# 637
# nonsingle
# 638
# nonsingle
# 639
# nonsingle
# 640
# single
# 641
# single
# 642
# nonsingle
# 643
# single
# 644
# nonsingle
# 645
# nonsingle
# 646
# single
# 647
# single
# 648
# single
# 649
# single
# 650
# single
# 651
# nonsingle
# 652
# single
# 653
# single
# 654
# single
# 655
# nonsingle
# 656
# single
# 657
# nonsingle
# 658
# single
# 659
# nonsingle
# 660
# nonsingle
# 661
# single
# 662
# single
# 663
# single
# 664
# nonsingle
# 665
# nonsingle
# 666
# single
# 667
# single
# 668
# single
# 669
# nonsingle
# 670
# nonsingle
# 671
# nonsingle
# 672
# single
# 673
# single
# 674
# single
# 675
# single
# 676
# single
# 677
# single
# 678
# nonsingle
# 679
# nonsingle
# 680
# single
# 681
# single
# 682
# single
# 683
# nonsingle
# 684
# nonsingle
# 685
# nonsingle
# 686
# nonsingle
# 687
# single
# 688
# single
# 689
# nonsingle
# 690
# nonsingle
# 691
# nonsingle
# 692
# single
# 693
# single
# 694
# single
# 695
# single
# 696
# single
# 697
# single
# 698
# nonsingle
# 699
# single
# 700
# nonsingle
# 701
# single
# 702
# nonsingle
# 703
# single
# 704
# nonsingle
# 705
# single
# 706
# single
# 707
# single
# 708
# single
# 709
# nonsingle
# 710
# single
# 711
# single
# 712
# nonsingle
# 713
# single
# 714
# single
# 715
# single
# 716
# single
# 717
# single
# 718
# single
# 719
# single
# 720
# nonsingle
# 721
# nonsingle
# 722
# single
# 723
# single
# 724
# nonsingle
# 725
# single
# 726
# nonsingle
# 727
# single
# 728
# nonsingle
# 729
# nonsingle
# 730
# single
# 731
# single
# 732
# single
# 733
# single
# 734
# single
# 735
# single
# 736
# nonsingle
# 737
# single
# 738
# single
# 739
# single
# 740
# single
# 741
# nonsingle
# 742
# nonsingle
# 743
# nonsingle
# 744
# single
# 745
# nonsingle
# 746
# nonsingle
# 747
# single
# 748
# nonsingle
# 749
# single
# 750
# nonsingle
# 751
# nonsingle
# 752
# single
# 753
# single
# 754
# nonsingle
# 755
# nonsingle
# 756
# single
# 757
# single
# 758
# single
# 759
# single
# 760
# single
# 761
# single
# 762
# single
# 763
# nonsingle
# 764
# single
# 765
# nonsingle
# 766
# single
# 767
# single
# 768
# nonsingle
# 769
# single
# 770
# single
# 771
# single
# 772
# single
# 773
# single
# 774
# nonsingle
# 775
# single
# 776
# single
# 777
# single
# 778
# single
# 779
# nonsingle
# 780
# single
# 781
# nonsingle
# 782
# single
# 783
# nonsingle
# 784
# single
# 785
# single
# 786
# single
# 787
# nonsingle
# 788
# nonsingle
# 789
# single
# 790
# single
# 791
# single
# 792
# nonsingle
# 793
# single
# 794
# single
# 795
# single
# 796
# single
# 797
# single
# 798
# single
# 799
# nonsingle
# 800
# single
# 801
# nonsingle
# 802
# nonsingle
# 803
# nonsingle
# 804
# single
# 805
# single
# 806
# single
# 807
# single
# 808
# single
# 809
# nonsingle
# 810
# single
# 811
# single
# 812
# single
# 813
# nonsingle
# 814
# single
# 815
# single
# 816
# single
# 817
# nonsingle
# 818
# single
# 819
# nonsingle
# 820
# nonsingle
# 821
# single
# 822
# single
# 823
# nonsingle
# 824
# nonsingle
# 825
# single
# 826
# single
# 827
# nonsingle
# 828
# single
# 829
# single
# 830
# nonsingle
# 831
# nonsingle
# 832
# single
# 833
# single
# 834
# single
# 835
# nonsingle
# 836
# single
# 837
# single
# 838
# single
# 839
# single
# 840
# single
# 841
# single
# 842
# single
# 843
# single
# 844
# single
# 845
# single
# 846
# nonsingle
# 847
# single
# 848
# nonsingle
# 849
# nonsingle
# 850
# nonsingle
# 851
# single
# 852
# nonsingle
# 853
# nonsingle
# 854
# nonsingle
# 855
# nonsingle
# 856
# nonsingle
# 857
# single
# 858
# nonsingle
# 859
# single
# 860
# nonsingle
# 861
# nonsingle
# 862
# single
# 863
# nonsingle
# 864
# single
# 865
# single
# 866
# nonsingle
# 867
# single
# 868
# single
# 869
# nonsingle
# 870
# single
# 871
# nonsingle
# 872
# single
# 873
# single
# 874
# nonsingle
# 875
# single
# 876
# single
# 877
# single
# 878
# single
# 879
# nonsingle
# 880
# nonsingle
# 881
# single
# 882
# single
# 883
# single
# 884
# single
# 885
# nonsingle
# 886
# single
# 887
# single
# 888
# nonsingle
# 889
# single
# 890
# single
# 891
# single
# 892
# nonsingle
# 893
# single
# 894
# single
# 895
# nonsingle
# 896
# single
# 897
# single
# 898
# nonsingle
# 899
# single
# 900
# nonsingle
# 901
# single
# 902
# single
# 903
# nonsingle
# 904
# nonsingle
# 905
# nonsingle
# 906
# nonsingle
# 907
# single
# 908
# single
# 909
# nonsingle
# 910
# single
# 911
# nonsingle
# 912
# nonsingle
# 913
# single
# 914
# nonsingle
# 915
# nonsingle
# 916
# nonsingle
# 917
# nonsingle
# 918
# single
# 919
# single
# 920
# nonsingle
# 921
# nonsingle
# 922
# nonsingle
# 923
# nonsingle
# 924
# nonsingle
# 925
# nonsingle
# 926
# single
# 927
# single
# 928
# single
# 929
# single
# 930
# single
# 931
# nonsingle
# 932
# single
# 933
# single
# 934
# single
# 935
# nonsingle
# 936
# single
# 937
# single
# 938
# single
# 939
# single
# 940
# nonsingle
# 941
# nonsingle
# 942
# single
# 943
# nonsingle
# 944
# nonsingle
# 945
# single
# 946
# nonsingle
# 947
# single
# 948
# single
# 949
# nonsingle
# 950
# single
# 951
# single
# 952
# single
# 953
# single
# 954
# single
# 955
# nonsingle
# 956
# single
# 957
# single
# 958
# single
# 959
# single
# 960
# nonsingle
# 961
# single
# 962
# single
# 963
# single
# 964
# single
# 965
# single
# 966
# single
# 967
# single
# 968
# nonsingle
# 969
# single
# 970
# single
# 971
# nonsingle
# 972
# nonsingle
# 973
# single
# 974
# single
# 975
# single
# 976
# nonsingle
# 977
# single
# 978
# single
# 979
# single
# 980
# nonsingle
# 981
# nonsingle
# 982
# single
# 983
# nonsingle
# 984
# single
# 985
# single
# 986
# single
# 987
# nonsingle
# 988
# single
# 989
# single
# 990
# single
# 991
# nonsingle
# 992
# nonsingle
# 993
# single
# 994
# single
# 995
# nonsingle
# 996
# single
# 997
# single
# 998
# single
# 999
# single
# 1000
# single
# 1001
# single
# 1002
# single
# 1003
# single
# 1004
# single
# 1005
# nonsingle
# 1006
# nonsingle
# 1007
# single
# 1008
# nonsingle
# 1009
# single
# 1010
# nonsingle
# 1011
# single
# 1012
# nonsingle
# 1013
# nonsingle
# 1014
# single
# 1015
# single
# 1016
# nonsingle
# 1017
# single
# 1018
# nonsingle
# 1019
# single
# 1020
# single
# 1021
# single
# 1022
# single
# 1023
# nonsingle
# 1024
# nonsingle
# 1025
# single
# 1026
# single
# 1027
# single
# 1028
# single
# 1029
# single
# 1030
# nonsingle
# 1031
# nonsingle
# 1032
# single
# 1033
# nonsingle
# 1034
# single
# 1035
# single
# 1036
# nonsingle
# 1037
# single
# 1038
# single
# 1039
# single
# 1040
# nonsingle
# 1041
# nonsingle
# 1042
# single
# 1043
# single
# 1044
# nonsingle
# 1045
# nonsingle
# 1046
# single
# 1047
# single
# 1048
# single
# 1049
# single
# 1050
# nonsingle
# 1051
# single
# 1052
# nonsingle
# 1053
# single
# 1054
# single
# 1055
# single
# 1056
# nonsingle
# 1057
# single
# 1058
# nonsingle
# 1059
# single
# 1060
# single
# 1061
# single
# 1062
# single
# 1063
# nonsingle
# 1064
# single
# 1065
# nonsingle
# 1066
# nonsingle
# 1067
# single
# 1068
# nonsingle
# 1069
# nonsingle
# 1070
# nonsingle
# 1071
# single
# 1072
# nonsingle
# 1073
# nonsingle
# 1074
# single
# 1075
# nonsingle
# 1076
# single
# 1077
# nonsingle
# 1078
# nonsingle
# 1079
# nonsingle
# 1080
# single
# 1081
# nonsingle
# 1082
# single
# 1083
# nonsingle
# 1084
# single
# 1085
# nonsingle
# 1086
# single
# 1087
# nonsingle
# 1088
# single
# 1089
# single
# 1090
# single
# 1091
# single
# 1092
# nonsingle
# 1093
# nonsingle
# 1094
# nonsingle
# 1095
# single
# 1096
# single
# 1097
# single
# 1098
# single
# 1099
# single
# 1100
# single
# 1101
# single
# 1102
# single
# 1103
# single
# 1104
# nonsingle
# 1105
# nonsingle
# 1106
# single
# 1107
# single
# 1108
# nonsingle
# 1109
# nonsingle
# 1110
# single
# 1111
# nonsingle
# 1112
# single
# 1113
# single
# 1114
# single
# 1115
# single
# 1116
# nonsingle
# 1117
# single
# 1118
# single
# 1119
# single
# 1120
# single
# 1121
# single
# 1122
# single
# 1123
# nonsingle
# 1124
# single
# 1125
# nonsingle
# 1126
# single
# 1127
# nonsingle
# 1128
# single
# 1129
# nonsingle
# 1130
# nonsingle
# 1131
# single
# 1132
# nonsingle
# 1133
# nonsingle
# 1134
# single
# 1135
# nonsingle
# 1136
# nonsingle
# 1137
# single
# 1138
# nonsingle
# 1139
# nonsingle
# 1140
# nonsingle
# 1141
# nonsingle
# 1142
# single
# 1143
# nonsingle
# 1144
# single
# 1145
# single
# 1146
# single
# 1147
# single
# 1148
# single
# 1149
# single
# 1150
# single
# 1151
# nonsingle
# 1152
# single
# 1153
# nonsingle
# 1154
# nonsingle
# 1155
# single
# 1156
# single
# 1157
# single
# 1158
# single
# 1159
# single
# 1160
# single
# 1161
# single
# 1162
# single
# 1163
# nonsingle
# 1164
# nonsingle
# 1165
# single
# 1166
# nonsingle
# 1167
# single
# 1168
# nonsingle
# 1169
# nonsingle
# 1170
# single
# 1171
# single
# 1172
# nonsingle
# 1173
# single
# 1174
# nonsingle
# 1175
# nonsingle
# 1176
# single
# 1177
# single
# 1178
# nonsingle
# 1179
# single
# 1180
# single
# 1181
# single
# 1182
# single
# 1183
# single
# 1184
# nonsingle
# 1185
# single
# 1186
# single
# 1187
# nonsingle
# 1188
# nonsingle
# 1189
# single
# 1190
# single
# 1191
# single
# 1192
# single
# 1193
# nonsingle
# 1194
# single
# 1195
# single
# 1196
# nonsingle
# 1197
# nonsingle
# 1198
# nonsingle
# 1199
# nonsingle
# 1200
# nonsingle
# 1201
# single
# 1202
# single
# 1203
# single
# 1204
# single
# 1205
# single
# 1206
# single
# 1207
# nonsingle
# 1208
# single
# 1209
# single
# 1210
# nonsingle
# 1211
# single
# 1212
# single
# 1213
# single
# 1214
# single
# 1215
# single
# 1216
# single
# 1217
# nonsingle
# 1218
# single
# 1219
# nonsingle
# 1220
# single
# 1221
# nonsingle
# 1222
# single
# 1223
# single
# 1224
# nonsingle
# 1225
# single
# 1226
# single
# 1227
# single
# 1228
# nonsingle
# 1229
# single
# 1230
# single
# 1231
# single
# 1232
# single
# 1233
# nonsingle
# 1234
# nonsingle
# 1235
# nonsingle
# 1236
# single
# 1237
# single
# 1238
# single
# 1239
# single
# 1240
# single
# 1241
# nonsingle
# 1242
# single
# 1243
# single
# 1244
# nonsingle
# 1245
# nonsingle
# 1246
# single
# 1247
# nonsingle
# 1248
# single
# 1249
# single
# 1250
# nonsingle
# 1251
# nonsingle
# 1252
# nonsingle
# 1253
# single
# 1254
# single
# 1255
# nonsingle
# 1256
# nonsingle
# 1257
# nonsingle
# 1258
# single
# 1259
# nonsingle
# 1260
# single
# 1261
# nonsingle
# 1262
# single
# 1263
# single
# 1264
# single
# 1265
# nonsingle
# 1266
# single
# 1267
# nonsingle
# 1268
# single
# 1269
# single
# 1270
# nonsingle
# 1271
# single
# 1272
# single
# 1273
# single
# 1274
# nonsingle
# 1275
# single
# 1276
# nonsingle
# 1277
# single
# 1278
# single
# 1279
# single
# 1280
# nonsingle
# 1281
# single
# 1282
# nonsingle
# 1283
# nonsingle
# 1284
# single
# 1285
# nonsingle
# 1286
# nonsingle
# 1287
# single
# 1288
# nonsingle
# 1289
# single
# 1290
# single
# 1291
# single
# 1292
# nonsingle
# 1293
# nonsingle
# 1294
# single
# 1295
# nonsingle
# 1296
# single
# 1297
# nonsingle
# 1298
# nonsingle
# 1299
# single
# 1300
# nonsingle
# 1301
# single
# 1302
# nonsingle
# 1303
# single
# 1304
# single
# 1305
# single
# 1306
# single
# 1307
# single
# 1308
# nonsingle
# C:\Users\Yehonatan\AppData\Local\Temp\ipykernel_8668\3678155418.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['livability'][p] = 'D'

# %% [markdown]
# ## other nans

# %%
# fill fare nan as the average of 3 class . 

t_class = df[df['pclass'] == 3]
t_class_mean = t_class['fare'].mean()
df.at[1043, 'fare'] = t_class_mean

# fill nan embarked to be an class of itself
df.at[61, 'embarked'] = 'M'
df.at[829, 'embarked'] = 'M'

# %%
title, last_name = parse_name(df) # parse names and fill name as last name to categorize it 
df['name'] = last_name 
df['cabin'] = df['cabin'].fillna(5) # all the nans in cabin are a caegory 5 
df = cat_to_numeric(df)

survived = df['survived']
passenger_id = df['passengerid'].values

# %%
corr_mat = df.corr()
corr_mat['survived'].sort_values(ascending=False)
# Out:
# survived       1.000000
# sex            0.543351
# livability     0.488907
# fare           0.257307
# cabin          0.169258
# embarked       0.118026
# parch          0.081629
# name           0.017314
# relatives      0.016639
# passengerid   -0.005007
# sibsp         -0.035322
# ticket        -0.047298
# age           -0.066088
# pclass        -0.338481
# Name: survived, dtype: float64

# %%
#df = df.drop(columns=['cabin', 'name', 'ticket']) # for now drop cabin

# %%
df = df.drop(columns=['survived','passengerid','name', 'sibsp', 'ticket']) 
# 'name', 'sibsp', 'ticket' dropped those columns logic in unstandradized models file p value filter

# %% [markdown]
# # scaling

# %%
numerical_columns_selector = selector(dtype_exclude=int)
categorical_columns_selector = selector(dtype_include=int)

numerical_columns = numerical_columns_selector(df)
categorical_columns = categorical_columns_selector(df)

# %%
print(numerical_columns)
print(categorical_columns)
# Out:
# ['age', 'fare']
# ['pclass', 'sex', 'parch', 'cabin', 'embarked', 'relatives', 'livability']

# %%
categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")
numerical_preprocessor = StandardScaler()

# %%
preprocessor = ColumnTransformer([
    ('one-hot-encoder', categorical_preprocessor, categorical_columns),
    ('standard_scaler', numerical_preprocessor, numerical_columns)])

# %%
model = make_pipeline(preprocessor, SVC(kernel='rbf') )

# %%
# divide back into train test sets 
df_train = df.iloc[:890,:]
df_test = df.iloc[891:,:]

x_train = df_train
y_train = survived.iloc[:890]


x_test = df_test
y_test = survived.iloc[891:]

# %%
model = model.fit(x_train, y_train)
y_train_pred = model.predict(x_train)

# %% [markdown]
# # models

# %%
# # rf
# clf = LogisticRegression(random_state=9, max_iter=500, solver = 'newton-cg') 
# clf = SGDClassifier(max_iter=1000, tol=1e-3)
# clf = SVC(kernel='poly')
# clf = KNeighborsClassifier()
# clf = GradientBoostingClassifier(n_estimators=40, learning_rate=0.2,max_depth=2, random_state=0)
# clf = LinearSVC(random_state=0, tol=1e-5)

# %%
precision, recall, f_1, support = precision_recall_fscore_support(y_train, y_train_pred, average='binary')
accuracy = accuracy_score(y_train, y_train_pred)
print('accuracy :', np.round(accuracy,3))
print('precision :', np.round(precision,3))
print('recall :', np.round(recall,3))
print('f_score :', np.round(f_1,3))
# Out:
# accuracy : 0.853
# precision : 0.898
# recall : 0.696
# f_score : 0.784

# %%
cv_5_accuracy = cross_val_score(model, x_train , y_train, cv=5, scoring='accuracy')
cv_5_precision = cross_val_score(model, x_train , y_train, cv=5, scoring='precision')
cv_5_recall = cross_val_score(model, x_train , y_train, cv=5, scoring='recall')
cv_5_f1 = cross_val_score(model, x_train , y_train, cv=5, scoring='f1')

print('cv_avg_accuracy :', np.round(cv_5_accuracy.mean(),3))
print('cv_avg_precision', np.round(cv_5_precision.mean(),3))
print('cv_avg_recall', np.round(cv_5_recall.mean(),3))
print('cv_avg_fscore :', np.round(cv_5_f1.mean(),3))
# Out:
# cv_avg_accuracy : 0.826
# cv_avg_precision 0.846
# cv_avg_recall 0.67
# cv_avg_fscore : 0.747

# %%
y_pred = cross_val_predict(model, x_train, y_train, cv=3)
cnf_mx = confusion_matrix(y_train, y_pred)
print(cnf_mx)
print(classification_report(y_train, y_pred))
# Out:
# [[508  40]
#  [112 230]]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.93      0.87       548
#          1.0       0.85      0.67      0.75       342
#
#     accuracy                           0.83       890
#    macro avg       0.84      0.80      0.81       890
# weighted avg       0.83      0.83      0.82       890

# %%
y_pred = cross_val_predict(model, x_train, y_train, cv=3, method = 'decision_function')
precisions, recalls, thresholds_2 = precision_recall_curve(y_train, y_pred)
plt.plot(thresholds_2, precisions[:-1], 'b--', label='Precision')
plt.plot(thresholds_2, recalls[:-1], 'g-', label='Recall')
plt.xlabel('Threshold')
plt.legend(loc=('lower left'))
plt.xlim([-2,2])
# Out:
# (-2.0, 2.0)

# %%
plt.plot(recalls[:-1], precisions[:-1], 'b--')
plt.xlabel('Recall')
plt.ylabel('Precision')
# Out:
# Text(0, 0.5, 'Precision')

# %%
fpr, tpr, thresholds_1 = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
display.plot()
plt.show()

# %% [markdown]
# # test

# %%
y_test_pred = model.predict(x_test)
y_test_pred = y_test_pred.astype(int)

# %%
submission_df = pd.DataFrame({'Passengerid': passenger_id[891:], 'Survived': y_test_pred})
submission_df.to_csv('titanic_pred_30.csv', index = False)
